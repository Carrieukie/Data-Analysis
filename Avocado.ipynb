# %%
import pandas as pd

df = pd.read_csv("datasets/avocado.csv")
df = df.copy()[df['type'] == "organic"]
df['Date'] = pd.to_datetime(df['Date'])

df.head()
# Out:
#       Unnamed: 0       Date  AveragePrice  Total Volume   4046    4225  4770  \
# 9126           0 2015-12-27          1.83        989.55   8.16   88.59   0.0
# 9127           1 2015-12-20          1.89       1163.03  30.24  172.14   0.0
# 9128           2 2015-12-13          1.85        995.96  10.44  178.70   0.0
# 9129           3 2015-12-06          1.84       1158.42  90.29  104.18   0.0
# 9130           4 2015-11-29          1.94        831.69   0.00   94.73   0.0
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  region
# 9126      892.80      892.80        0.00          0.0  organic  2015  Albany
# 9127      960.65      960.65        0.00          0.0  organic  2015  Albany
# 9128      806.82      806.82        0.00          0.0  organic  2015  Albany
# 9129      963.95      948.52       15.43          0.0  organic  2015  Albany
# 9130      736.96      736.96        0.00          0.0  organic  2015  Albany

# %%
df.tail()
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7 2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8 2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9 2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
df["AveragePrice"].head()
# Out:
# 9126    1.83
# 9127    1.89
# 9128    1.85
# 9129    1.84
# 9130    1.94
# Name: AveragePrice, dtype: float64

# %%
albany = df[df["region"] == "Albany"]
albany.head()
# Out:
#       Unnamed: 0       Date  AveragePrice  Total Volume   4046    4225  4770  \
# 9126           0 2015-12-27          1.83        989.55   8.16   88.59   0.0
# 9127           1 2015-12-20          1.89       1163.03  30.24  172.14   0.0
# 9128           2 2015-12-13          1.85        995.96  10.44  178.70   0.0
# 9129           3 2015-12-06          1.84       1158.42  90.29  104.18   0.0
# 9130           4 2015-11-29          1.94        831.69   0.00   94.73   0.0
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  region
# 9126      892.80      892.80        0.00          0.0  organic  2015  Albany
# 9127      960.65      960.65        0.00          0.0  organic  2015  Albany
# 9128      806.82      806.82        0.00          0.0  organic  2015  Albany
# 9129      963.95      948.52       15.43          0.0  organic  2015  Albany
# 9130      736.96      736.96        0.00          0.0  organic  2015  Albany

# %%
albany.index
# Out:
# Int64Index([ 9126,  9127,  9128,  9129,  9130,  9131,  9132,  9133,  9134,
#              9135,
#             ...
#             17603, 17604, 17605, 17606, 17607, 17608, 17609, 17610, 17611,
#             17612],
#            dtype='int64', length=169)

# %%
albany.set_index('Date', inplace = True)

# %%
albany
# Out:
#             Unnamed: 0  AveragePrice  Total Volume    4046    4225  4770  \
# Date
# 2015-12-27           0          1.83        989.55    8.16   88.59   0.0
# 2015-12-20           1          1.89       1163.03   30.24  172.14   0.0
# 2015-12-13           2          1.85        995.96   10.44  178.70   0.0
# 2015-12-06           3          1.84       1158.42   90.29  104.18   0.0
# 2015-11-29           4          1.94        831.69    0.00   94.73   0.0
# ...                ...           ...           ...     ...     ...   ...
# 2018-02-04           7          1.52       4124.96  118.38  420.36   0.0
# 2018-01-28           8          1.32       6987.56  433.66  374.96   0.0
# 2018-01-21           9          1.54       3346.54   14.67  253.01   0.0
# 2018-01-14          10          1.47       4140.95    7.30  301.87   0.0
# 2018-01-07          11          1.54       4816.90   43.51  412.17   0.0
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# Date
# 2015-12-27      892.80      892.80        0.00          0.0  organic  2015
# 2015-12-20      960.65      960.65        0.00          0.0  organic  2015
# 2015-12-13      806.82      806.82        0.00          0.0  organic  2015
# 2015-12-06      963.95      948.52       15.43          0.0  organic  2015
# 2015-11-29      736.96      736.96        0.00          0.0  organic  2015
# ...                ...         ...         ...          ...      ...   ...
# 2018-02-04     3586.22     3586.22        0.00          0.0  organic  2018
# 2018-01-28     6178.94     6178.94        0.00          0.0  organic  2018
# 2018-01-21     3078.86     3078.86        0.00          0.0  organic  2018
# 2018-01-14     3831.78     3831.78        0.00          0.0  organic  2018
# 2018-01-07     4361.22     4357.89        3.33          0.0  organic  2018
#
#             region
# Date
# 2015-12-27  Albany
# 2015-12-20  Albany
# 2015-12-13  Albany
# 2015-12-06  Albany
# 2015-11-29  Albany
# ...            ...
# 2018-02-04  Albany
# 2018-01-28  Albany
# 2018-01-21  Albany
# 2018-01-14  Albany
# 2018-01-07  Albany
#
# [169 rows x 13 columns]

# %%
albany.index
# Out:
# DatetimeIndex(['2015-12-27', '2015-12-20', '2015-12-13', '2015-12-06',
#                '2015-11-29', '2015-11-22', '2015-11-15', '2015-11-08',
#                '2015-11-01', '2015-10-25',
#                ...
#                '2018-03-11', '2018-03-04', '2018-02-25', '2018-02-18',
#                '2018-02-11', '2018-02-04', '2018-01-28', '2018-01-21',
#                '2018-01-14', '2018-01-07'],
#               dtype='datetime64[ns]', name='Date', length=169, freq=None)

# %%
albany.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany['AveragePrice'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany['AveragePrice'].rolling(25).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany.sort_index(inplace = True)
# Out:
# /home/karis/.local/lib/python3.8/site-packages/pandas/core/frame.py:6388: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().sort_index(

# %%
albany['AveragePrice'].rolling(25).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany['price25ma'] = albany['AveragePrice'].rolling(25).mean()
# Out:
# /tmp/ipykernel_19597/890699681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   albany['price25ma'] = albany['AveragePrice'].rolling(25).mean()

# %%
albany.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume   4046    4225  4770  \
# Date
# 2015-01-04          51          1.79       1373.95  57.42  153.88   0.0
# 2015-01-11          50          1.77       1182.56  39.00  305.12   0.0
# 2015-01-18          49          1.93       1118.47   8.02  178.78   0.0
# 2015-01-25          48          1.89       1115.89  14.87  148.72   0.0
# 2015-02-01          47          1.83       1228.51  33.12   99.36   0.0
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# Date
# 2015-01-04     1162.65     1162.65         0.0          0.0  organic  2015
# 2015-01-11      838.44      838.44         0.0          0.0  organic  2015
# 2015-01-18      931.67      931.67         0.0          0.0  organic  2015
# 2015-01-25      952.30      952.30         0.0          0.0  organic  2015
# 2015-02-01     1096.03     1096.03         0.0          0.0  organic  2015
#
#             region  price25ma
# Date
# 2015-01-04  Albany        NaN
# 2015-01-11  Albany        NaN
# 2015-01-18  Albany        NaN
# 2015-01-25  Albany        NaN
# 2015-02-01  Albany        NaN

# %%
albany.dropna().head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume   4046    4225  4770  \
# Date
# 2015-06-21          27          2.09       1053.73  17.59  107.87   0.0
# 2015-06-28          26          2.02       1200.61  22.35  124.70   0.0
# 2015-07-05          25          2.04       1573.19  50.69  183.90   0.0
# 2015-07-12          24          2.01       1175.34  34.27   92.17   0.0
# 2015-07-19          23          2.08       1076.23  50.86  112.36   0.0
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# Date
# 2015-06-21      928.27      928.27         0.0          0.0  organic  2015
# 2015-06-28     1053.56     1053.56         0.0          0.0  organic  2015
# 2015-07-05     1338.60     1338.60         0.0          0.0  organic  2015
# 2015-07-12     1048.90     1048.90         0.0          0.0  organic  2015
# 2015-07-19      913.01      913.01         0.0          0.0  organic  2015
#
#             region  price25ma
# Date
# 2015-06-21  Albany     1.8748
# 2015-06-28  Albany     1.8840
# 2015-07-05  Albany     1.8948
# 2015-07-12  Albany     1.8980
# 2015-07-19  Albany     1.9056

# %%
df.values.tolist()[0]
# Out:
# [0,
#  Timestamp('2015-12-27 00:00:00'),
#  1.83,
#  989.55,
#  8.16,
#  88.59,
#  0.0,
#  892.8,
#  892.8,
#  0.0,
#  0.0,
#  'organic',
#  2015,
#  'Albany']

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
len(df['region'].unique())
# Out:
# 54

# %%
graph_df = pd.DataFrame()

for region in df['region'].unique():
    print(region)
    region_df = df.copy()[df['region'] == region ]
    region_df.set_index("Date", inplace = True)
    region_df.sort_index(inplace = True)
    region_df[f'{region}_price25ma'] = region_df['AveragePrice'].rolling(25).mean()
    
    if graph_df.empty:
        graph_df = region_df[[f'{region}_price25ma']]
    
    else:
        graph_df = graph_df.join(region_df[[f'{region}_price25ma']])
# Out:
# Albany
# Atlanta
# BaltimoreWashington
# Boise
# Boston
# BuffaloRochester
# California
# Charlotte
# Chicago
# CincinnatiDayton
# Columbus
# DallasFtWorth
# Denver
# Detroit
# GrandRapids
# GreatLakes
# HarrisburgScranton
# HartfordSpringfield
# Houston
# Indianapolis
# Jacksonville
# LasVegas
# LosAngeles
# Louisville
# MiamiFtLauderdale
# Midsouth
# Nashville
# NewOrleansMobile
# NewYork
# Northeast
# NorthernNewEngland
# Orlando
# Philadelphia
# PhoenixTucson
# Pittsburgh
# Plains
# Portland
# RaleighGreensboro
# RichmondNorfolk
# Roanoke
# Sacramento
# SanDiego
# SanFrancisco
# Seattle
# SouthCarolina
# SouthCentral
# Southeast
# Spokane
# StLouis
# Syracuse
# Tampa
# TotalUS
# West
# WestTexNewMexico

# %%
graph_df.sort_index(inplace = True)
graph_df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
