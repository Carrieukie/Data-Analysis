# %%
import pandas as pd

df = pd.read_csv("datasets/minimumwage.csv")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Year       State  State.Minimum.Wage  \
# 0           0             0  1968     Alabama             0.00000
# 1           1             1  1968      Alaska             2.10000
# 2           2             2  1968     Arizona             0.46800
# 3           3             3  1968    Arkansas             0.15625
# 4           4             4  1968  California             1.65000
#
#    State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                             0.00                  1.15
# 1                            15.61                  1.15
# 2                             3.48                  1.15
# 3                             1.16                  1.15
# 4                            12.26                  1.15
#
#    Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                               8.55                    1.15
# 1                               8.55                    2.10
# ...

# %%
gb = df.groupby("State")
gb.get_group('Alabama').set_index('Year').head()
# Out:
#       Unnamed: 0  Unnamed: 0.1    State  State.Minimum.Wage  \
# Year
# 1968           0             0  Alabama                 0.0
# 1969          54            54  Alabama                 0.0
# 1970         108           108  Alabama                 0.0
# 1971         162           162  Alabama                 0.0
# 1972         216           216  Alabama                 0.0
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# Year
# 1968                              0.0                  1.15
# 1969                              0.0                  1.15
# 1970                              0.0                  1.30
# 1971                              0.0                  1.30
# 1972                              0.0                  1.60
#
#       Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# Year
# 1968                               8.55                    1.15
# 1969                               8.11                    1.15
# ...

# %%
act_min_wage = pd.DataFrame()
for name, group in df.groupby("State"):
        if act_min_wage.empty:
            act_min_wage= group.set_index("Year")[["Effective.Minimum.Wage.2020.Dollars"]].rename(columns={"Effective.Minimum.Wage.2020.Dollars":name})
        else:
            act_min_wage= act_min_wage.join(group.set_index("Year")[["Effective.Minimum.Wage.2020.Dollars"]].rename(columns={"Effective.Minimum.Wage.2020.Dollars":name}))
act_min_wage.head()
# Out:
#       Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1968     8.55   15.61     8.55      8.55       12.26      8.55        10.41
# 1969     8.11   14.80     8.11      8.11       11.63      8.11         9.87
# 1970     8.67   14.00     8.67      8.67       11.00      8.67        10.67
# 1971     8.30   13.41     8.30      8.30       10.54      8.30        10.22
# 1972     9.90   12.99     9.90      9.90       10.21      9.90        11.45
#
#       Delaware  District of Columbia  Florida  ...  Tennessee  Texas  \
# Year                                           ...
# 1968      9.29                  9.29     8.55  ...       8.55   8.55
# 1969      8.81                  8.81     8.11  ...       8.11   8.11
# 1970      8.67                 10.67     8.67  ...       8.67   8.67
# 1971      8.30                 10.22     8.30  ...       8.30   8.30
# 1972      9.90                  9.90     9.90  ...       9.90   9.90
#
# ...

# %%
act_min_wage.describe()
# Out:
#          Alabama     Alaska    Arizona   Arkansas  California   Colorado  \
# count  53.000000  53.000000  53.000000  53.000000   53.000000  53.000000
# mean    7.991887   9.917736   8.435849   8.186604    9.161321   8.432453
# std     0.903959   1.852213   1.227011   0.918102    1.415633   1.199128
# min     6.420000   7.620000   6.610000   6.610000    6.630000   6.610000
# 25%     7.340000   8.590000   7.610000   7.520000    8.050000   7.610000
# 50%     7.900000   9.260000   8.340000   8.050000    9.130000   8.390000
# 75%     8.390000  10.510000   8.740000   8.700000    9.820000   8.960000
# max    10.330000  15.610000  12.140000  10.330000   13.000000  12.140000
#
#        Connecticut   Delaware  District of Columbia    Florida  ...  \
# count    53.000000  53.000000             53.000000  53.000000  ...
# mean      9.212830   8.454717              9.295472   8.247358  ...
# std       1.106907   0.781246              1.632104   0.840023  ...
# ...

# %%
act_min_wage.corr()
# Out:
#                        Alabama    Alaska   Arizona  Arkansas  California  \
# Alabama               1.000000  0.620364  0.494796  0.815863    0.281291
# Alaska                0.620364  1.000000  0.441018  0.619306    0.668420
# Arizona               0.494796  0.441018  1.000000  0.885807    0.732276
# Arkansas              0.815863  0.619306  0.885807  1.000000    0.619974
# California            0.281291  0.668420  0.732276  0.619974    1.000000
# Colorado              0.506270  0.444483  0.994981  0.892103    0.738742
# Connecticut           0.380878  0.646909  0.688033  0.636162    0.895479
# Delaware              0.714823  0.646148  0.717137  0.831495    0.736683
# District of Columbia  0.183245  0.332957  0.820889  0.617050    0.796175
# Florida               0.843128  0.589012  0.755036  0.904296    0.547788
# Georgia               1.000000  0.620364  0.494796  0.815863    0.281291
# Guam                  0.874244  0.785670  0.584997  0.819658    0.473115
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Year       State  State.Minimum.Wage  \
# 0           0             0  1968     Alabama             0.00000
# 1           1             1  1968      Alaska             2.10000
# 2           2             2  1968     Arizona             0.46800
# 3           3             3  1968    Arkansas             0.15625
# 4           4             4  1968  California             1.65000
#
#    State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                             0.00                  1.15
# 1                            15.61                  1.15
# 2                             3.48                  1.15
# 3                             1.16                  1.15
# 4                            12.26                  1.15
#
#    Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                               8.55                    1.15
# 1                               8.55                    2.10
# ...

# %%
issue_df = df[df["Effective.Minimum.Wage.2020.Dollars"] == 0 ]
